# %%
# %config IPCompleter.greedy=True


import importlib
import angles
import util
# import numpy as np
import sys

print(sys.version_info)
# print(np.__version__)
importlib.reload(angles)
importlib.reload(util)

structure, residue_list, polypeptide = util.main_load('ubiq', '1ubq.pdb')
# Out:
# sys.version_info(major=3, minor=6, micro=3, releaselevel='final', serial=0)
# Number of residues in chain: 134
# Removing 58 hetero residues
# Removed 0 hydrogen atoms
# Chain now has 76 residues
# building peptides
# chain
# diff is [-0.57800102  1.13100052 -0.273     ]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.74900055  0.40299988  1.01499987]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.66799927  0.66900063  0.90899992]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [ 1.10900116  0.58100128  0.4460001 ]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [-0.88700104  0.40600204  0.84000015]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [ 0.95700073  0.95500183  0.02600002]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.46800041  0.22999954  1.20800018]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.91599846  0.03300095 -0.98600006]
# dot prod is 0.0
# /anaconda3/lib/python3.6/site-packages/Bio/PDB/Atom.py:217: RuntimeWarning: invalid value encountered in sqrt
#   return numpy.sqrt(numpy.dot(diff, diff))
# 1.13.3
# accept
# diff is [-1.03399849 -0.6780014  -0.3920002 ]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [ 0.95899963 -0.88399887  0.10200024]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.29599953 -0.32799911 -1.24400043]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [ 0.3010006  -1.2460022   0.36600018]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [ 0.28899956 -0.22499847 -1.26199961]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.52499962 -1.19499969  0.21999979]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [ 0.81200027 -0.87599945 -0.53999996]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-1.13000107 -0.62100029  0.3039999 ]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [ 0.10099983 -1.17000008  0.59100008]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [-1.26000023 -0.38899994 -0.02799988]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.81999969 -0.77300072 -0.69200039]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [ 0.34100151  1.28100014 -0.15600014]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 1.01900101 -0.22599983  0.81200027]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [-0.47999954  0.31000137  1.20499992]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.77199936 -0.99300003  0.3730011 ]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.47600174 -0.56599998 -1.09700012]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [-1.23099899  0.36300087  0.32999992]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.29299927 -0.27700043  1.26500034]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.52400208 -1.08300018 -0.53600025]
# dot prod is -2.0
# 1.13.3
# diff is [-1.09500122 -0.04800034 -0.74400043]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [-0.63000107  0.28800011  1.14000034]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [ 0.73500061 -0.87100029  0.64400005]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.0909996  -0.93000031 -0.92000008]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-1.28199768  0.41200066  0.02099991]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.18200302  0.06399918  1.28999996]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [ 0.64200211 -1.13399887  0.23200035]
# dot prod is -2.0
# 1.13.3
# diff is [-1.30700302 -0.15999985  0.2699995 ]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.73999786 -0.19300079  1.08600044]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.10900116 -1.26799965 -0.31099892]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.95299911  0.04199982  0.89900017]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.05399704  1.03800011 -0.81800079]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [-0.33399963 -0.88199997 -0.91499901]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [-1.11100006  0.72800064  0.08799934]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.51599884 -1.07299995 -0.59599876]
# dot prod is -2.0
# 1.13.3
# diff is [-0.89499855  0.91500092 -0.36000061]
# dot prod is -1.0842021724855044e-19
# 1.13.3
# diff is [-0.95999908 -0.96199989  0.04500008]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [-1.02499962  0.74900055 -0.32600021]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [ 0.71900177  0.86700058  0.65200043]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [ 0.71800041 -0.79800034 -0.74300003]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.83399963 -0.36000061  0.93799973]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [ 0.72200012  0.10299873 -1.0890007 ]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.05200005 -1.33300018  0.00500107]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [ 1.29100037 -0.01600075  0.21899986]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.43099785 -1.0529995   0.65600014]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [-0.97999954  0.89599991  0.02499962]
# dot prod is 2.0
# 1.13.3
# accept
# diff is [-0.86499977 -0.31000137 -0.93299866]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.10299873  0.78299904 -1.0539999 ]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ -9.99450684e-04  -1.20300102e+00  -6.11000061e-01]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.76799965 -0.26599884  1.04100037]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.38600159  1.21700096 -0.25800037]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [-0.14900017 -0.70599937 -1.10000038]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 1.27499962  0.21899986 -0.25      ]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [-0.81900024  0.76399994 -0.66600037]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.10199928 -0.05200005 -1.32599974]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.97200012  0.92300034  0.03100014]
# dot prod is -2.0
# 1.13.3
# diff is [ 0.20800018 -0.91899872  0.92999983]
# dot prod is -2.0
# 1.13.3
# diff is [-0.26300049  0.64499855  1.1050005 ]
# dot prod is -2.0
# 1.13.3
# diff is [ 1.28100014 -0.20299911  0.32800007]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [-0.07699966  0.06900024  1.28100109]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 1.04999924  0.79599762 -0.11500168]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.0720005  -0.50899887  1.18700027]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.86200142  0.92100143  0.36199951]
# dot prod is -3.6893488147419103e+19
# 1.13.3
# diff is [ 0.69100189 -0.96900177  0.47200012]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [ 0.52599716  1.10099792  0.42399979]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# diff is [ 1.2179985  -0.51900101  0.01399994]
# dot prod is 0.0
# 1.13.3
# accept
# diff is [-0.59999847  0.70199966  0.95400047]
# dot prod is 1.0842021724855044e-19
# 1.13.3
# accept
# diff is [-0.30500031  0.53099823  1.16899872]
# dot prod is 3.6893488147419103e+19
# 1.13.3
# 20
# ERROR: expected only one polypeptide from PDB structure
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b723db5bfb9> in <module>()
#      13 importlib.reload(util)
#      14
# ---> 15 structure, residue_list, polypeptide = util.main_load('ubiq', '1ubq.pdb')
#
# ~/Documents/DevProjects/bio/protein/util.py in main_load(model_name, filename)
#      60     if len(polypeptides) != 1:
#      61         print(f'ERROR: expected only one polypeptide from PDB structure')
# ---> 62         exit()
#      63
#      64     polypeptide = polypeptides[0]
#
# NameError: name 'exit' is not defined
